# %%
import pandas

# %%
Week_5_test = pandas.read_csv ('week_5.csv')

# %%
Week_5_test
# Out:
#         City name      Posting site  Order in the route Frame type  \
# 0        Randwick  Sydney Warehouse               100.0      Fixed
# 1        Randwick  Sydney Warehouse               100.0      Fixed
# 2        Randwick  Sydney Warehouse               200.0      Fixed
# 3        Randwick  Sydney Warehouse               200.0      Fixed
# 4        Randwick  Sydney Warehouse               300.0      Fixed
# 5        Randwick  Sydney Warehouse               300.0      Fixed
# 6        Randwick  Sydney Warehouse               400.0      Fixed
# 7        Randwick  Sydney Warehouse               400.0      Fixed
# 8        Randwick  Sydney Warehouse               500.0      Fixed
# 9        Randwick  Sydney Warehouse               500.0      Fixed
# 10       Randwick  Sydney Warehouse               600.0      Fixed
# 11       Randwick  Sydney Warehouse               600.0      Fixed
# 12    North Bondi  Sydney Warehouse               700.0      Fixed
# ...

# %%
import sklearn.cluster

# %%
Week_5_audience = pandas.read_csv ('week_5_audience_1.csv')

# %%
Week_5_audience
# Out:
#                                                Location  Health insurance  \
# 0               12023037 - Bridge St  Before Gresham St            119.96
# 1               12023038 - Bridge St  Before Gresham St            119.96
# 2          12023039 - Carrington St  Before Margaret St            120.14
# 3          12023040 - Carrington St  Before Margaret St            126.87
# 4                 12023041 - Phillip St  Before Bent St            119.99
# 5                 12023042 - Phillip St  Before Bent St            119.99
# 6                  12023043 - York St After Margaret St            120.10
# 7                 12023044 - York St  After Margaret St            126.77
# 8          12023045 - Carrington St  Before Margaret St            120.11
# 9          12023046 - Carrington St  Before Margaret St            120.11
# 10                12023047 - Carrington St  Wynyard Stn            120.12
# 11                12023048 - Carrington St  Wynyard Stn            134.12
# ...

# %%
import sklearn.linear_model
import pandas
import matplotlib.pyplot
Regressor = sklearn.linear_model.TheilSenRegressor()
X = Week_5_audience [['Health insurance', 'Credit cards']]
y = Week_5_audience.index
Regressor.fit(X,y)
Predictions = Regressor.predict(X)

# %%
import sklearn.linear_model

# %%
clf = sklearn.linear_model.LogisticRegression(C=1000000)

# %%
X = Week_5_audience[['Health insurance']]
y = Week_5_audience.Location

# %%
clf.fit(X, y)
#so as you can see, I've started to do some analysis but I really had NO IDEA what I was doing, just trying to 
#understand if there was anything important in this that I could use...
# Out:
# LogisticRegression(C=1000000, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)

# %%
#I then thought, hey, maybe I should do some clustering?
health_Insurance = (Week_5_audience ['Health insurance'])


hI = []
for x in health_Insurance:
    hI.append(float(x))

# %%
import sklearn.cluster
Clusterer = sklearn.cluster.KMeans(
                                   n_clusters=3)
Clusters = Clusterer.fit_predict(Week_5_audience [['Health insurance', 'Credit cards']])
Week_5_audience ['Cluster'] = Clusters

Clusters
# Out:
# array([1, 1, 1, ..., 1, 1, 2], dtype=int32)

# %% [raw]
# Interesting_Columns = Week_5_audience [['Health insurance', 'Location']]
# Interesting_Columns

# %%
#K nearest neighbours?? like the real estate classification 
#- predict what price - if we were to build a new one how much would we charge for it?

# %%
#then I thought, ok let's try doing some decision tree stuff with it. Then maybe I could have a process that 
#kind of relayed instructions on what constitutes the right pricing for a panel
import sklearn.tree
X = Week_5_audience [['Health insurance','Credit cards']]
y = Week_5_audience.index

# %%
dtf = sklearn.tree.DecisionTreeClassifier(max_depth=1)

# %%
dtf.fit(X, y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=1,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
# !pip install pydot3
# Out:
# ...
# done
#   Stored in directory: /Users/smarc/Library/Caches/pip/wheels/e7/cf/30/f0faa11f82de89257725b7faecfaa2caca796a316d1f6e9b23
# Successfully built pydot3
# ...

# %%
dtc = sklearn.tree.DecisionTreeClassifier(max_depth=2, criterion='entropy')
dtc.fit(X, y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=2,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
#so I was getting somewhere, but where? So I thought, let's plot!!!
# %matplotlib inline 
import matplotlib
Colouring = numpy.array(['red','green','blue'])
matplotlib.pyplot.scatter(Week_5_audience.Health insurance, Week_5_audience.Credit cards
                          color=Colouring[Clusters])
Matplotlib.pyplot.scatter(Clusterer.cluster_centers_[:,0],
                          Clusterer.cluster_centers_[:,1],
                          marker=“+”, s=30)
#and then it all seemed to gall down. and I realised I wasn't actually making any predictions (or sense!)
# Out:
#   File "<ipython-input-83-0a8b4cef7110>", line 5
#     matplotlib.pyplot.scatter(Week_5_audience.Health insurance, Week_5_audience.Credit cards
#                                                              ^
# SyntaxError: invalid syntax

# %%
S=sklearn.metrics.silhouette_score(Interesting_columns,
                                   Clusters)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-92e14bfc5f91> in <module>()
# ----> 1 S=sklearn.metrics.silhouette_score(Interesting_columns,
#       2                                    Clusters)
#
# NameError: name 'Interesting_columns' is not defined
