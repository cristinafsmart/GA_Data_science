# %%
import pandas

# %%
scoreboard = pandas.read_csv ('all scoreboard 2016.csv', index_col = 'SIGN_ID')

# %%
scoreboard
# Out:
#           COMPANY SITE_IDENTIFICATION_CODE DESCRIPTION  \
# SIGN_ID
# 56743    JCDecaux                     8382  08821116X2
# 56745    JCDecaux                     8371  08821206X2
# 56746    JCDecaux                     8324  08821207X2
# 56747    JCDecaux                     8309  08821212X2
# 56748    JCDecaux                     8331  08821213X2
# 56749    JCDecaux                     8370  08821223X2
# 56750    JCDecaux                     8378  08821228X2
# 56751    JCDecaux                     8384  08821229X2
# 56752    JCDecaux                     8332  08821232X2
# 56753    JCDecaux                     8369  08821234X2
# 56754    JCDecaux                     8389  08821235X2
# 56755    JCDecaux                     8377  08821239X2
# 56756    JCDecaux                     8311  08821240X2
# 56757    JCDecaux                     8333  08821244X2
# 56758    JCDecaux                     8379  08822100X2
# 56759    JCDecaux                     8383  08822104X2
# ...

# %%
len(scoreboard)
# Out:
# 11556

# %%
list(scoreboard)
# Out:
# ['COMPANY',
#  'SITE_IDENTIFICATION_CODE',
#  'DESCRIPTION',
#  'ADDRESS',
#  'SUBURB',
#  'FORMAT',
#  'ILLUMINATION_TYPE',
#  'ILLUMINATION_PERIOD',
#  'VERTICAL_SIZE',
#  'HORIZONTAL_SIZE',
#  'FACE_HEIGHT',
#  'MOVEMENT_TYPE',
#  'MOVEMENT_DURATION',
#  'MOVEMENT_TRANSITION',
#  'ORIENTATION',
#  'CATEGORY',
#  'MARKET',
#  'LOCATION_NAME',
#  'DEPOT_NUMBER',
#  'SHOPPING_CENTRE_LEVEL',
#  'CORRIDOR_TYPE',
#  'ATTRACTOR_TYPE',
#  'DEPT_STORE_VICINITY',
#  'ESCALATOR_VICINITY',
#  'SUPERMARKET_VICINITY',
#  'NUM_PANELS',
#  'STATION_SECTION',
#  'PERCENT_BOARD',
#  'PERCENT_ALIGHT',
#  'SIGN_LINKS',
#  'PLATFORM_LAYOUT',
#  'PLATFORM_POSITION',
#  'NUM_PLATFORMS_VIS',
#  'ARCHIVED',
#  'LONGITUDE',
#  'LATITUDE',
#  'AREA',
#  'reach_7_total',
#  'reach_14_total',
#  'reach_21_total',
#  'reach_28_total',
#  'reach_35_total',
#  'reach_42_total',
#  'reach_49_total',
#  'reach_56_total',
#  'reach_63_total',
#  'reach_70_total',
#  'reach_77_total',
#  'reach_84_total',
# ...

# %%
scoreboard ['contacts_7_total'
]
# Out:
# SIGN_ID
# 56743     36754
# 56745    109492
# 56746      9823
# 56747      3589
# 56748    161538
# 56749     74098
# 56750     26763
# 56751     37452
# 56752      9436
# 56753     48569
# 56754     26377
# 56755     21876
# 56756     56868
# 56757     10301
# 56758     59032
# 56759     13492
# 56760     38608
# 56761     43586
# 56762      7865
# 56763     78568
# 56764     75364
# 56765     71161
# 56766     39131
# 56767     47750
# 56768    130309
# 56769     51127
# 56770     15732
# 56771     10439
# 56772     50369
# 56773     63393
#           ...
# 40336     51315
# 40338     10322
# 40340     34057
# 40342         0
# 40344     14878
# 40346     37056
# 40348     14609
# 40350     52432
# 40352     52029
# 40354         0
# 40356     27938
# 40358      9886
# 40360     15544
# 40362       474
# 40364     34623
# 40366     10689
# 40368     20726
# 40370      7542
# 40371     44391
# 40372     19578
# 40373      5793
# 40374     47502
# 40375      2591
# 40376         0
# ...
